# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# Load YOLO model
model = YOLO(r"best.pt")

# Image path
image_path = r"images3.jpg"

# Run prediction
results = model.predict(source=image_path, conf=0.25)

# Get the first result and plot it
output_image = results[0].plot()

# Convert BGR to RGB for Matplotlib
output_image_rgb = cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB)

# Display using Matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(output_image_rgb)
plt.axis('off')
plt.title("YOLO11-nano Prediction")
plt.show()
# Out:
# image 1/1 d:\computer vision projects\PPE\images3.jpg: 448x640 3 face_nomasks, 2 hand_nogloves, 3 head_whelmets, 3 persons, 3 vests, 89.8ms
# Speed: 4.0ms preprocess, 89.8ms inference, 4.6ms postprocess per image at shape (1, 3, 448, 640)
